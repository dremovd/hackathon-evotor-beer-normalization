# %% [markdown]
# # Пример работы API построенного на модели линейной классификации которая использует только текст

# %%
import pandas as pd

# %%
# Исключены несколько строк у которых нарушен формат
# Кодировка utf-8
data = pd.read_csv('../MASTER_DATA_beer_hackaton_fixed.csv.gz')

# %% [markdown]
# Метод API:
#
# https://qr-kassa.ru:9876/name
#
# Ожидает в теле запрос JSON: {'name': name}

# %%
import requests
import tqdm

results = []
for name in tqdm.tqdm_notebook(data['o.item_name'].sample(50).values):
    response = requests.post('https://qr-kassa.ru:9876/name', json={'name': name}).json()
    results.append(response)

results = pd.DataFrame(results)
# Out:
# HBox(children=(IntProgress(value=0, max=50), HTML(value='')))

# %%
targets = [
    'Алкоголь', 'Объем', 'Производитель', 'Бренд',
    'Саб-бренд', 'Тип упаковки', 'Мультипак', 'тип'
]

# %%
results[['name', 'Наименование'] + targets]
# Out:
#                                                  name  \
# 0      Пиво Жигули Барное бутылка 0,5 л (ОптовикАлко)
# 1              Пиво Жигулевское светлое 4,1% 1,35лпэт
# 2   Пиво св, "Балтика классическое" №3 в ж/б,Тула ...
# 3                       Пиво ЛИДСКОЕ классическое 1,5
# 4   Пиво темное АФАНАСИЙ ЭКСПЕРИМЕНТАЛЬНОЕ об 4.5%...
# 5                               пиво Жигулевское 1,5л
# 6   Пиво "Лидское бархатное" темное 4.8% 0.5л (Бел...
# 7                          пиво белый медведь светлое
# 8                     Гёссер пиво св. 4,7% 1,35л ПЭТ
# 9   Пиво светлое банка пастеризов. "Охота" крепкое...
# 10                    пиво жотецкий гусь светлое 0.5л
# 11                          балтика №4 алк.5,6%об с/б
# 12                   Пиво « Горьковское" св. 0.47 ст.
# 13               Пиво "Krusovice Imperial")  0,5л бан
# 14               Пиво Жатецкий гусь ж/б 0.9 л. Самара
# 15      ПИВО БАЛТИКА КУЛЕР СВЕТЛОЕ АЛК 4.7% 0.45Л Ж/Б
# 16  Пиво ТРИ ШУРУПА светл пастериз, 4.8%об, ПЭТ,1.42л
# 17                    Пиво Козел светлое 4% 0,5л бут.
# 18  Пиво светлое фильтрованное пастеризованное `Кр...
# 19           пиво старый мельник мягкое 0,5л  4,3 алк
# 20                             Бархатное темное 1.35л
# 21                        Халзан классическое 1,5 Пэт
# 22                       пиво жигули барное 4,9% 0.9л
# 23                    Пиво Балтика №7  0.45л ж/б 5,4%
# 24  Пиво светлое "Балтика Кулер светлое" 0.47 л. в/у.
# 25  Напиток пивной Seht and Rileys Garag Hard Ling...
# 26              пиво "Кроненбург 1664" светлое 0,46л.
# 27  Пивной напиток Жатецкий Гусь Черный паст. ст/б...
# 28                     Пиво светлое Карлсберг 0.45ж.б
# 29                      Пиво Невское светлое ст 0.44л
# 30                       Пиво '' Жигулевское" 1 л ж/б
# 31  Пивной напиток «Доктор Дизель Секси Лайм» паст...
# 32                               крым нахимовское с/б
# 33                                  пиво немецкое0.5л
# 34             Пиво светлое "Халзан".4.5%,0.5л,стекло
# 35                         пиво пшеничное 0.5 л. 5,0%
# 36                     Варварка- пивоварка ПЭТ 1.35л.
# 37   "Велкопоповицкий Козел Тёмное".3,7%, Бутылка ...
# 38                           пиво.крым.крепкое.пэт.1л
# 39                              Ячменное поле с.б 0.5
# 40                                      Пиво BUD ст/б
# 41                                            Лидское
# 42     Клаустайлер Нефильтрованное 0% 0.33л. Германия
# 43  Пиво светлое "Большая кружка Светлое" пастериз...
# 44                       Золотая бочька светлое 0.5ст
# 45                                       крым светлое
# 46  Пиво светлое Старый мельник из бочонка мягкое 0.5
# 47                        пиво охота крепкое ж/б 0.45
# 48                         Пиво Балтика 7. 1.35 л п/б
# 49    Тройной пшеничный Эль  6.9%  0.75л бут  (9). шт
#
#                                          Наименование  Алкоголь  Объем  \
# 0        ЖИГУЛИ БАРНОЕ - Светлое - 4.9% - 0.5л Стекло     0.049   0.50
# 1            ЖИГУЛЕВСКОЕ - Светлое - 4.1% - 1.35л ПЭТ     0.041   1.35
# 2                БАЛТИКА - Светлое - 4.8% - 0.9л ж.б.     0.048   0.90
# 3                 ЛИДСКОЕ - Светлое - 5.1% - 1.5л ПЭТ     0.051   1.50
# 4                 АФАНАСИЙ - Темное - 4.5% - 1.0л ПЭТ     0.045   1.00
# 5             ЖИГУЛЕВСКОЕ - Светлое - 4.0% - 1.5л ПЭТ     0.040   1.50
# 6               ЛИДСКОЕ - Темное - 4.8% - 0.5л Стекло     0.048   0.50
# 7       БЕЛЫЙ МЕДВЕДЬ - Светлое - 5.0% - 0.45л Стекло     0.050   0.45
# 8                 GOSSER - Светлое - 4.7% - 1.35л ПЭТ     0.047   1.35
# 9                 ОХОТА - Светлое - 8.1% - 0.45л ж.б.     0.081   0.45
# 10        ZATECKY GUS - Светлое - 4.6% - 0.48л Стекло     0.046   0.48
# 11             БАЛТИКА - Темное - 5.6% - 0.47л Стекло     0.056   0.47
# 12        ГОРЬКОВСКОЕ - Светлое - 4.7% - 0.47л Стекло     0.047   0.47
# 13             KRUSOVICE - Светлое - 5.0% - 0.5л ж.б.     0.050   0.50
# 14           ZATECKY GUS - Светлое - 4.6% - 0.9л ж.б.     0.046   0.90
# 15              БАЛТИКА - Светлое - 4.7% - 0.45л ж.б.     0.047   0.45
# 16            ТРИ ШУРУПА - Светлое - 4.8% - 1.42л ПЭТ     0.048   1.42
# 17  VELKOPOPOVICKY KOZEL - Светлое - 4.0% - 0.5л С...     0.040   0.50
# 18            ЖИГУЛЕВСКОЕ - Светлое - 4.4% - 1.5л ПЭТ     0.044   1.50
# 19      СТАРЫЙ МЕЛЬНИК - Светлое - 4.3% - 0.5л Стекло     0.043   0.50
# 20              БАРХАТНОЕ - Темное - 4.6% - 1.35л ПЭТ     0.046   1.35
# 21                 ХАЛЗАН - Светлое - 4.5% - 1.5л ПЭТ     0.045   1.50
# 22       ЖИГУЛИ БАРНОЕ - Светлое - 4.9% - 0.9л Стекло     0.049   0.90
# 23              БАЛТИКА - Светлое - 5.4% - 0.45л ж.б.     0.054   0.45
# 24             БАЛТИКА - Светлое - 4.7% - 4.7л стекло     0.047   4.70
# 25  SETH & RILEY`S GARAGE - Светлое - 4.6% - 0.44л...     0.046   0.44
# 26        KRONENBOURG - Светлое - 4.5% - 0.46л Стекло     0.045   0.46
# 27         ZATECKY GUS - Темное - 3.5% - 0.48л Стекло     0.035   0.48
# 28            CARLSBERG - Светлое - 4.6% - 0.45л ж.б.     0.046   0.45
# 29            НЕВСКОЕ - Светлое - 4.6% - 0.44л Стекло     0.046   0.44
# 30           ЖИГУЛЕВСКОЕ - Светлое - 4.5% - 1.0л ж.б.     0.045   1.00
# 31      DOCTOR DIESIL - Светлое - 4.0% - 0.48л Стекло     0.040   0.48
# 32         НАХИМОВСКОЕ - Светлое - 5.0% - 0.5л Стекло     0.050   0.50
# 33            НЕМЕЦКОЕ - Светлое - 4.2% - 0.5л Стекло     0.042   0.50
# 34              ХАЛЗАН - Светлое - 4.5% - 0.5л Стекло     0.045   0.50
# 35    ПЕННАЯ КОЛЛЕКЦИЯ - Светлое - 5.0% - 0.5л Стекло     0.050   0.50
# 36    ВАРВАРКА ПИВОВАРКА - Светлое - 4.6% - 1.35л ПЭТ     0.046   1.35
# 37  VELKOPOPOVICKY KOZEL - Темное - 3.7% - 0.5л Ст...     0.037   0.50
# 38                   КРЫМ - Светлое - 7.0% - 1.0л ПЭТ     0.070   1.00
# 39       ЯЧМЕННОЕ ПОЛЕ - Светлое - 4.5% - 0.5л Стекло     0.045   0.50
# 40                BUD - Светлое - 5.0% - 0.47л Стекло     0.050   0.47
# 41             ЛИДСКОЕ - Светлое - 5.1% - 0.5л Стекло     0.051   0.50
# 42        CLAUSTHALER - Светлое - 0.0% - 0.33л Стекло     0.000   0.33
# 43        БОЛЬШАЯ КРУЖКА - Светлое - 4.0% - 1.35л ПЭТ     0.040   1.35
# 44      ЗОЛОТАЯ БОЧКА - Светлое - 4.7% - 0.45л Стекло     0.047   0.45
# 45                   КРЫМ - Светлое - 4.4% - 0.5л ПЭТ     0.044   0.50
# 46      СТАРЫЙ МЕЛЬНИК - Светлое - 4.3% - 0.5л Стекло     0.043   0.50
# 47                ОХОТА - Светлое - 8.1% - 0.45л ж.б.     0.081   0.45
# 48               БАЛТИКА - Светлое - 5.4% - 1.35л ПЭТ     0.054   1.35
# 49   ТРОЙНОЙ ПШЕН.ЭЛЬ - Светлое - 7.5% - 0.75л Стекло     0.075   0.75
#
#                          Производитель                  Бренд Саб-бренд  \
# 0     Московская пивоваренная компания          ЖИГУЛИ БАРНОЕ
# 1                             AB InBev            ЖИГУЛЕВСКОЕ
# 2                              Балтика                БАЛТИКА
# 3                         Лидское пиво                ЛИДСКОЕ
# 4                             Афанасий               АФАНАСИЙ
# 5                              Хмелёфф            ЖИГУЛЕВСКОЕ
# 6                         Лидское пиво                ЛИДСКОЕ
# 7                                 Efes          БЕЛЫЙ МЕДВЕДЬ
# 8                             Heineken                 GOSSER
# 9                             Heineken                  ОХОТА
# 10                             Балтика            ZATECKY GUS
# 11                             Балтика                БАЛТИКА
# 12                             Балтика            ГОРЬКОВСКОЕ
# 13                            Heineken              KRUSOVICE  IMPERIAL
# 14                             Балтика            ZATECKY GUS
# 15                             Балтика                БАЛТИКА
# 16                                Efes             ТРИ ШУРУПА
# 17                                Efes   VELKOPOPOVICKY KOZEL
# 18  Пивобезалкогольный Комбинат «Крым»            ЖИГУЛЕВСКОЕ
# 19                                Efes         СТАРЫЙ МЕЛЬНИК
# 20                             Балтика              БАРХАТНОЕ
# 21                             Очаково                 ХАЛЗАН
# 22    Московская пивоваренная компания          ЖИГУЛИ БАРНОЕ
# 23                             Балтика                БАЛТИКА
# 24                             Балтика                БАЛТИКА
# 25                             Балтика  SETH & RILEY`S GARAGE
# 26                             Балтика            KRONENBOURG
# 27                             Балтика            ZATECKY GUS
# 28                             Балтика              CARLSBERG
# 29                             Балтика                НЕВСКОЕ
# 30                       Трехсосенское            ЖИГУЛЕВСКОЕ
# 31                            Heineken          DOCTOR DIESIL
# 32  Пивобезалкогольный Комбинат «Крым»            НАХИМОВСКОЕ
# 33     Барнаульский пивоваренный завод               НЕМЕЦКОЕ
# 34                             Очаково                 ХАЛЗАН
# 35                       Букет чувашии       ПЕННАЯ КОЛЛЕКЦИЯ
# 36                             Балтика     ВАРВАРКА ПИВОВАРКА
# 37                                Efes   VELKOPOPOVICKY KOZEL
# 38  Пивобезалкогольный Комбинат «Крым»                   КРЫМ
# 39                       Трехсосенское          ЯЧМЕННОЕ ПОЛЕ
# 40                            AB InBev                    BUD
# 41                        Лидское пиво                ЛИДСКОЕ
# 42                         clausthaler            CLAUSTHALER
# 43                             Балтика         БОЛЬШАЯ КРУЖКА
# 44                                Efes          ЗОЛОТАЯ БОЧКА
# 45  Пивобезалкогольный Комбинат «Крым»                   КРЫМ
# 46                                Efes         СТАРЫЙ МЕЛЬНИК
# 47                            Heineken                  ОХОТА
# 48                             Балтика                БАЛТИКА
# 49      Василеостровская Пивоварня ООО       ТРОЙНОЙ ПШЕН.ЭЛЬ
#
#    Тип упаковки  Мультипак      тип
# 0        Стекло        0.0  Светлое
# 1           ПЭТ        0.0  Светлое
# 2          ж.б.        0.0  Светлое
# 3           ПЭТ        0.0  Светлое
# 4           ПЭТ        0.0   Темное
# 5           ПЭТ        0.0  Светлое
# 6        Стекло        0.0   Темное
# 7        Стекло        0.0  Светлое
# 8           ПЭТ        0.0  Светлое
# 9          ж.б.        0.0  Светлое
# 10       Стекло        0.0  Светлое
# 11       Стекло        0.0   Темное
# 12       Стекло        0.0  Светлое
# 13         ж.б.        0.0  Светлое
# 14         ж.б.        0.0  Светлое
# 15         ж.б.        0.0  Светлое
# 16          ПЭТ        0.0  Светлое
# 17       Стекло        0.0  Светлое
# 18          ПЭТ        0.0  Светлое
# 19       Стекло        0.0  Светлое
# 20          ПЭТ        0.0   Темное
# 21          ПЭТ        0.0  Светлое
# 22       Стекло        0.0  Светлое
# 23         ж.б.        0.0  Светлое
# 24       стекло        0.0  Светлое
# 25       Стекло        0.0  Светлое
# 26       Стекло        0.0  Светлое
# 27       Стекло        0.0   Темное
# 28         ж.б.        0.0  Светлое
# 29       Стекло        0.0  Светлое
# 30         ж.б.        0.0  Светлое
# 31       Стекло        0.0  Светлое
# 32       Стекло        0.0  Светлое
# 33       Стекло        0.0  Светлое
# 34       Стекло        0.0  Светлое
# 35       Стекло        0.0  Светлое
# 36          ПЭТ        0.0  Светлое
# 37       Стекло        0.0   Темное
# 38          ПЭТ        0.0  Светлое
# 39       Стекло        0.0  Светлое
# 40       Стекло        0.0  Светлое
# 41       Стекло        0.0  Светлое
# 42       Стекло        0.0  Светлое
# 43          ПЭТ        0.0  Светлое
# 44       Стекло        0.0  Светлое
# 45          ПЭТ        0.0  Светлое
# 46       Стекло        0.0  Светлое
# 47         ж.б.        0.0  Светлое
# 48          ПЭТ        0.0  Светлое
# 49       Стекло        0.0  Светлое
